# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 7c525d69-aad8-4d94-9e42-92e2e1e5b2d3, 3, Finished, Available, Finished)

# %%
# %%sql
# create table if not exists Project_Lakehouse.gold_shipmode
# (
#     ShipMode_ID	Long	,
# Ship_Mode	string	,
# Created_TS	timestamp,
# Modified_TS timestamp
# )
# Out:
# StatementMeta(, 7c525d69-aad8-4d94-9e42-92e2e1e5b2d3, 4, Submitted, Running, Running)

# %%
Max_Date=spark.sql("select coalesce(max(Modified_TS),'1900-01-01') from Project_Lakehouse.gold_shipmode").first()[0]
