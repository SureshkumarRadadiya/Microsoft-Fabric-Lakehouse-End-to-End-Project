# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

from notebookutils import mssparkutils
# Out:
# StatementMeta(, 5fe5b0e8-9b9e-4ee2-83a7-eac1f009b74a, 3, Finished, Available, Finished)

# %%
mssparkutils.fs.mount("abfss://1df115cc-23f0-4d1d-9a90-aad986d02161@onelake.dfs.fabric.microsoft.com/f79a512c-ee42-4057-bc18-ce8433d05b40/Files","/Files")
# Out:
# StatementMeta(, 5fe5b0e8-9b9e-4ee2-83a7-eac1f009b74a, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 2a1843f8-941c-4882-841d-27cce1b9cdc1)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, 5fe5b0e8-9b9e-4ee2-83a7-eac1f009b74a, 5, Finished, Available, Finished)
# '/synfs/notebook/5fe5b0e8-9b9e-4ee2-83a7-eac1f009b74a/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/Current/")
# Out:
# StatementMeta(, 5fe5b0e8-9b9e-4ee2-83a7-eac1f009b74a, 9, Finished, Available, Finished)

# %%
check_files
# Out:
# StatementMeta(, 5fe5b0e8-9b9e-4ee2-83a7-eac1f009b74a, 10, Finished, Available, Finished)
# []

# %%
if check_files:
    mssparkutils.notebook.run('bronze_sales')
    mssparkutils.notebook.run('gold_customer')
    mssparkutils.notebook.run('gold_date')
    mssparkutils.notebook.run('gold_fact_sale')
    mssparkutils.notebook.run('gold_orderpriority')
    mssparkutils.notebook.run('gold_orderreturn')
    mssparkutils.notebook.run('gold_product')
    mssparkutils.notebook.run('gold_shipmode')
# Out:
# StatementMeta(, 5fe5b0e8-9b9e-4ee2-83a7-eac1f009b74a, 14, Finished, Available, Finished)
